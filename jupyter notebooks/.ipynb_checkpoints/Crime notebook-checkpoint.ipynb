# %%
import pandas as pd
import plotly as py

# %%
dataset = pd.read_csv('C:\\Police\\Crime Data\\2010-12\\2010-12-kent-street.csv')

# %%
dataset.shape
# Out:
# (12811, 12)

# %%
dataset.head()
# Out:
#    Crime ID    Month  Reported by Falls within  Longitude   Latitude  \
# 0       NaN  2010-12  Kent Police  Kent Police   0.968511  51.254106
# 1       NaN  2010-12  Kent Police  Kent Police   0.965899  51.244036
# 2       NaN  2010-12  Kent Police  Kent Police   0.962332  51.244504
# 3       NaN  2010-12  Kent Police  Kent Police   0.901978  51.229107
# 4       NaN  2010-12  Kent Police  Kent Police   0.900879  51.231437
#
#                     Location  LSOA code     LSOA name             Crime type  \
# 0  On or near Cherry Orchard  E01023987  Ashford 001B  Anti-social behaviour
# 1    On or near Herons Close  E01023987  Ashford 001B               Burglary
# 2      On or near The Square  E01023987  Ashford 001B            Other crime
# 3      On or near The Street  E01023988  Ashford 001C          Vehicle crime
# 4     On or near Church Lane  E01023988  Ashford 001C            Other crime
#
#    Last outcome category  Context
# 0                    NaN      NaN
# ...

# %%
dataset['LSOA name'] = dataset['LSOA name'].astype(str).str[:-4] #trims last 4 characters of LSOA name

# %%
datasetbkp = dataset.copy() # back up my dataset before deleting rows

# %%
dataset.drop(dataset.index[1000:]) #drops the rows after 1000
# Out:
#        Month Falls within  Longitude   Latitude  \
# 0    2010-12  Kent Police   0.968511  51.254106
# 1    2010-12  Kent Police   0.965899  51.244036
# 2    2010-12  Kent Police   0.962332  51.244504
# 3    2010-12  Kent Police   0.901978  51.229107
# 4    2010-12  Kent Police   0.900879  51.231437
# 5    2010-12  Kent Police   0.940806  51.206281
# 6    2010-12  Kent Police   0.900879  51.231437
# 7    2010-12  Kent Police   0.940806  51.206281
# 8    2010-12  Kent Police   0.938729  51.182660
# 9    2010-12  Kent Police   0.936538  51.182193
# 10   2010-12  Kent Police   0.936538  51.182193
# 11   2010-12  Kent Police   0.937911  51.183310
# 12   2010-12  Kent Police   0.876053  51.170808
# 13   2010-12  Kent Police   0.880066  51.172751
# 14   2010-12  Kent Police   0.881181  51.171131
# 15   2010-12  Kent Police   0.879190  51.170641
# 16   2010-12  Kent Police   0.880066  51.172751
# 17   2010-12  Kent Police   0.893193  51.192970
# ...

# %%
del dataset['Month'] #deletes columns  i don't want
# Out:
#           Longitude      Latitude
# count  12811.000000  12811.000000
# mean       0.721229     51.302749
# std        0.396593      0.111483
# min       -0.102286     50.937624
# 25%        0.391536     51.224106
# 50%        0.557449     51.338284
# 75%        1.083887     51.386305
# max        1.444049     51.515136

# %%
dataset_crimetype = dataset['Crime type'].groupby(dataset['LSOA name'])

# %%
print dataset_crimetype

# %%
def get_stats(group):
    '''function that calculates the min, max, number of rows and mean value per group.'''
    return {'min': group.min(), 'max': group.max(), 'count': group.count(), 'mean': group.mean()}

# %%
dataset_crimetype.describe().unstack()
# Out:
#                        count unique                    top freq
# LSOA name
# Ashford                  641      6  Anti-social behaviour  256
# Bexley                     4      3            Other crime    2
# Canterbury              1122      6  Anti-social behaviour  525
# City of London             1      1            Other crime    1
# Dartford                 824      6            Other crime  310
# Dover                    795      6  Anti-social behaviour  365
# Gravesham                873      5  Anti-social behaviour  429
# Maidstone               1125      6  Anti-social behaviour  432
# Medway                  2201      6  Anti-social behaviour  934
# Sevenoaks                634      6  Anti-social behaviour  248
# Shepway                  681      6  Anti-social behaviour  302
# Swale                   1164      6  Anti-social behaviour  522
# Thanet                  1327      6  Anti-social behaviour  596
# ...
